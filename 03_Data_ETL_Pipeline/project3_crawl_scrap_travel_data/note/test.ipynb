# %% [markdown]
# # Tải dữ liệu cities và language-codes
# - Tải dữ liệu cities từ https://simplemaps.com/data/world-cities và upload lên MongoDB
# - Tải dữ liệu language-codes từ https://datahub.io/core/language-codes và upload lên MongoDB

# %%
# Kiểm tra database và collection, tạo nếu chưa có
from pymongo import MongoClient
import pandas as pd

MONGO_URI = "mongodb://localhost:27017/"
DB_NAME = "smart_travel_v2"
COLLECTION_NAME = "world_cities"

client = MongoClient(MONGO_URI)

# Kiểm tra database đã tồn tại chưa
db_list = client.list_database_names()
if DB_NAME not in db_list:
    print(f"Database '{DB_NAME}' chưa tồn tại. Sẽ được tạo khi thêm dữ liệu đầu tiên.")
else:
    print(f"Database '{DB_NAME}' đã tồn tại.")

db = client[DB_NAME]

# Kiểm tra collection đã tồn tại chưa
col_list = db.list_collection_names()
if COLLECTION_NAME not in col_list:
    print(f"Collection '{COLLECTION_NAME}' chưa tồn tại. Sẽ được tạo khi thêm dữ liệu đầu tiên.")
else:
    print(f"Collection '{COLLECTION_NAME}' đã tồn tại.")

# Nếu muốn tạo collection thủ công (không cần thiết, MongoDB sẽ tự tạo khi insert)
if COLLECTION_NAME not in col_list:
    db.create_collection(COLLECTION_NAME)
    print(f"Đã tạo collection '{COLLECTION_NAME}'.")

# Lấy dữ liệu nếu collection đã có
collection = db[COLLECTION_NAME]
cities_cursor = collection.find({})
cities = list(cities_cursor)
print(f"Số lượng thành phố lấy được: {len(cities)}")
# Chuyển list cities thành DataFrame trước khi xử lý
if cities:
    df_cities = pd.DataFrame(cities)
    df_cities = df_cities[["city", "country", "lat", "lng", "iso2"]]
    df_cities["iso2"] = df_cities["iso2"].str.lower()
    display(df_cities.head())
else:
    print("Không có dữ liệu city nào trong collection.")
# Out:
# Database 'smart_travel_v2' đã tồn tại.
# Collection 'world_cities' đã tồn tại.
# Số lượng thành phố lấy được: 48059
#         city    country      lat       lng iso2
# 0      Tokyo      Japan  35.6870  139.7495   jp
# 1    Jakarta  Indonesia  -6.1750  106.8275   id
# 2      Delhi      India  28.6100   77.2300   in
# 3  Guangzhou      China  23.1300  113.2600   cn
# 4     Mumbai      India  19.0761   72.8775   in

# %% [markdown]
# # Lấy dữ liệu places từ API
# https://rapidapi.com/gmapplatform/api/google-map-places-new-v2/playground/apiendpoint_ea6640da-90f7-4e89-8590-508da9401990

# %%
from pymongo import MongoClient
import requests, json, os, time

# Các loại địa điểm muốn tìm
PLACE_TYPES = ["tourist_attraction", "restaurant", "lodging"]

# Lưu dữ liệu vào MongoDB collection 'places'
MONGO_URI = "mongodb://localhost:27017/"
DB_NAME = "smart_travel_v2"
COLLECTION_NAME = "places"

client = MongoClient(MONGO_URI)
db = client[DB_NAME]
if COLLECTION_NAME not in db.list_collection_names():
    db.create_collection(COLLECTION_NAME)
    print(f"Đã tạo collection '{COLLECTION_NAME}'.")
collection = db[COLLECTION_NAME]

# API info
url = "https://google-map-places-new-v2.p.rapidapi.com/v1/places:searchText"

# headers = {
# 	"x-rapidapi-key": "cf1b379a98msh116f2d78aa3d55ep1a4602jsndbd91f1a8bb4",
# 	"x-rapidapi-host": "google-map-places-new-v2.p.rapidapi.com",
# 	"Content-Type": "application/json",
# 	"X-Goog-FieldMask": "*"
# }

# headers = {
# 	"x-rapidapi-key": "ffbaceaaeamsh9084aa32f4d5dfdp13028bjsn2366c1d9a5c9",
# 	"x-rapidapi-host": "google-map-places-new-v2.p.rapidapi.com",
# 	"Content-Type": "application/json",
# 	"X-Goog-FieldMask": "*"
# }

headers = {
	"x-rapidapi-key": "9036bbd933mshe2c1df67124cf82p17e447jsn62bbd79e7831",
	"x-rapidapi-host": "google-map-places-new-v2.p.rapidapi.com",
	"Content-Type": "application/json",
	"X-Goog-FieldMask": "*"
}

if 'df_cities' in locals():
    for row in df_cities[25:26].itertuples(index=False): # lan  sau chay tu 25: hochiminh
        print(f"\nXử lý thành phố: {row.city}, {row.country}")
        city = row.city
        country = row.country
        lat = row.lat
        lng = row.lng
        iso2 = row.iso2
        city_name = f"{city.lower()}({country.lower()})"

        for place_type in PLACE_TYPES:
            textQuery = place_type.replace("_", " ") + f" in {city_name}"
            print(f"\nĐang tìm {place_type} tại {city_name}...")

            payload = {
                "textQuery": textQuery,
                "languageCode": "en",
                "regionCode": iso2,
                "rankPreference": 0,
                "includedType": place_type,
                "openNow": True,
                "minRating": 0,
                "maxResultCount": 100,
                "priceLevels": [],
                "strictTypeFiltering": True,
                "locationBias": {
                    "circle": {
                        "center": {"latitude": lat, "longitude": lng},
                        "radius": 10000
                    }
                }
            }

            next_page_token = None
            while True:
                if next_page_token:
                    payload["pageToken"] = next_page_token
                try:
                    r = requests.post(url, json=payload, headers=headers)
                    print(f"  -> HTTP status: {r.status_code}")
                    resp = r.json()

                    # nếu không phải 200 thì in rõ lỗi trả về
                    if r.status_code != 200:
                        print("  -> Lỗi HTTP:", r.status_code, "| Nội dung:", resp)
                        # nếu hết quota/rate limit thì dừng luôn
                        if r.status_code == 429:
                            print("  -> Bị rate-limit/hết quota, dừng lại hoặc đổi API key.")
                            break
                        else:
                            break

                    results = resp.get("places") or resp.get("results") or []
                    next_page_token = resp.get("nextPageToken") or resp.get("next_page_token")

                    if results:
                        for place in results:
                            place["search_type"] = place_type
                            place["city"] = city
                            place["country"] = country
                        inserted = collection.insert_many(results)
                        print(f"  -> Đã lưu {len(inserted.inserted_ids)} kết quả vào MongoDB.")
                    else:
                        print("  -> Không có kết quả.")

                    if not next_page_token:
                        break  # Không còn trang tiếp theo
                    time.sleep(1)  # tránh rate limit giữa các lần gọi
                except Exception as e:
                    print(f"  -> Exception xảy ra: {e}")
                    break
else:
    print("Không tìm thấy DataFrame df_cities. Hãy khởi tạo df_cities trước.")
# Out:
# Xử lý thành phố: Istanbul, Turkey
#
# Đang tìm tourist_attraction tại istanbul(turkey)...
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.
#
# Đang tìm restaurant tại istanbul(turkey)...
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.
#
# Đang tìm lodging tại istanbul(turkey)...
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.
#   -> HTTP status: 200
#   -> Đã lưu 20 kết quả vào MongoDB.

# %% [markdown]
# ## Tiền xử lý dữ liệu

# %%
# Kiểm tra database và collection, tạo nếu chưa có
from pymongo import MongoClient
import pandas as pd

MONGO_URI = "mongodb://localhost:27017/"
DB_NAME = "smart_travel_v2"
COLLECTION_NAME = "places"

client = MongoClient(MONGO_URI)

# Kiểm tra database đã tồn tại chưa
db_list = client.list_database_names()
if DB_NAME not in db_list:
    print(f"Database '{DB_NAME}' chưa tồn tại. Sẽ được tạo khi thêm dữ liệu đầu tiên.")
else:
    print(f"Database '{DB_NAME}' đã tồn tại.")

db = client[DB_NAME]

# Kiểm tra collection đã tồn tại chưa
col_list = db.list_collection_names()
if COLLECTION_NAME not in col_list:
    print(f"Collection '{COLLECTION_NAME}' chưa tồn tại. Sẽ được tạo khi thêm dữ liệu đầu tiên.")
else:
    print(f"Collection '{COLLECTION_NAME}' đã tồn tại.")

# Lấy dữ liệu nếu collection đã có
collection = db[COLLECTION_NAME]
places_cursor = collection.find({})
places = list(places_cursor)
# Out:
# Database 'smart_travel_v2' đã tồn tại.
# Collection 'places' đã tồn tại.

# %%
import json

print(json.dumps(places[200], indent=2, ensure_ascii=False, default=str))
# Out:
# {
#   "_id": "68c823f908482f98a7661446",
#   "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk",
#   "id": "ChIJ76KhEr-rNTERXYzy4QH-Xnk",
#   "types": [
#     "jewelry_store",
#     "finance",
#     "store",
#     "point_of_interest",
#     "establishment"
#   ],
#   "nationalPhoneNumber": "024 3826 7117",
#   "internationalPhoneNumber": "+84 24 3826 7117",
#   "formattedAddress": "130 P. Hàng Bạc, Hàng Buồm, Hoàn Kiếm, Hà Nội, Vietnam",
#   "addressComponents": [
#     {
#       "longText": "130",
#       "shortText": "130",
#       "types": [
#         "street_number"
#       ],
#       "languageCode": "en"
#     },
#     {
#       "longText": "Phố Hàng Bạc",
#       "shortText": "P. Hàng Bạc",
#       "types": [
#         "route"
#       ],
#       "languageCode": "vi"
#     },
#     {
#       "longText": "Phố cổ Hà Nội",
#       "shortText": "Phố cổ Hà Nội",
#       "types": [
#         "neighborhood",
#         "political"
#       ],
#       "languageCode": "vi"
#     },
#     {
#       "longText": "Hoàn Kiếm",
#       "shortText": "Hoàn Kiếm",
#       "types": [
#         "administrative_area_level_2",
#         "political"
#       ],
#       "languageCode": "vi"
#     },
#     {
#       "longText": "Hà Nội",
#       "shortText": "Hà Nội",
#       "types": [
#         "administrative_area_level_1",
#         "political"
#       ],
#       "languageCode": "vi"
#     },
#     {
#       "longText": "Vietnam",
#       "shortText": "VN",
#       "types": [
#         "country",
#         "political"
#       ],
#       "languageCode": "en"
#     }
#   ],
#   "plusCode": {
#     "globalCode": "7PH72VM2+M9",
#     "compoundCode": "2VM2+M9 Hoàn Kiếm, Hanoi, Vietnam"
#   },
#   "location": {
#     "latitude": 21.0341679,
#     "longitude": 105.850923
#   },
#   "viewport": {
#     "low": {
#       "latitude": 21.0327839697085,
#       "longitude": 105.84957636970849
#     },
#     "high": {
#       "latitude": 21.035481930291507,
#       "longitude": 105.8522743302915
#     }
#   },
#   "rating": 4.7,
#   "googleMapsUri": "https://maps.google.com/?cid=8745706810439273565&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQABgBIAA",
#   "regularOpeningHours": {
#     "openNow": true,
#     "periods": [
#       {
#         "open": {
#           "day": 0,
#           "hour": 8,
#           "minute": 0
#         },
#         "close": {
#           "day": 0,
#           "hour": 21,
#           "minute": 30
#         }
#       },
#       {
#         "open": {
#           "day": 1,
#           "hour": 8,
#           "minute": 0
#         },
#         "close": {
#           "day": 1,
#           "hour": 21,
#           "minute": 30
#         }
#       },
#       {
#         "open": {
#           "day": 2,
#           "hour": 8,
#           "minute": 0
#         },
#         "close": {
#           "day": 2,
#           "hour": 21,
#           "minute": 30
#         }
#       },
#       {
#         "open": {
#           "day": 3,
#           "hour": 8,
#           "minute": 0
#         },
#         "close": {
#           "day": 3,
#           "hour": 21,
#           "minute": 30
#         }
#       },
#       {
#         "open": {
#           "day": 4,
#           "hour": 8,
#           "minute": 0
#         },
#         "close": {
#           "day": 4,
#           "hour": 21,
#           "minute": 30
#         }
#       },
#       {
#         "open": {
#           "day": 5,
#           "hour": 8,
#           "minute": 0
#         },
#         "close": {
#           "day": 5,
#           "hour": 21,
#           "minute": 30
#         }
#       },
#       {
#         "open": {
#           "day": 6,
#           "hour": 8,
#           "minute": 0
#         },
#         "close": {
#           "day": 6,
#           "hour": 21,
#           "minute": 30
#         }
#       }
#     ],
#     "weekdayDescriptions": [
#       "Monday: 8:00 AM – 9:30 PM",
#       "Tuesday: 8:00 AM – 9:30 PM",
#       "Wednesday: 8:00 AM – 9:30 PM",
#       "Thursday: 8:00 AM – 9:30 PM",
#       "Friday: 8:00 AM – 9:30 PM",
#       "Saturday: 8:00 AM – 9:30 PM",
#       "Sunday: 8:00 AM – 9:30 PM"
#     ],
#     "nextCloseTime": "2025-09-15T14:30:00Z"
#   },
#   "utcOffsetMinutes": 420,
#   "adrFormatAddress": "<span class=\"street-address\">130 P. Hàng Bạc</span>, <span class=\"extended-address\">Hàng Buồm</span>, <span class=\"locality\">Hoàn Kiếm</span>, <span class=\"region\">Hà Nội</span>, <span class=\"country-name\">Vietnam</span>",
#   "businessStatus": "OPERATIONAL",
#   "userRatingCount": 683,
#   "iconMaskBaseUri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet",
#   "iconBackgroundColor": "#4B96F3",
#   "displayName": {
#     "text": "Quang Huy Gemstone",
#     "languageCode": "en"
#   },
#   "primaryTypeDisplayName": {
#     "text": "Jewelry store",
#     "languageCode": "en"
#   },
#   "currentOpeningHours": {
#     "openNow": true,
#     "periods": [
#       {
#         "open": {
#           "day": 0,
#           "hour": 8,
#           "minute": 0,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 21
#           }
#         },
#         "close": {
#           "day": 0,
#           "hour": 21,
#           "minute": 30,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 21
#           }
#         }
#       },
#       {
#         "open": {
#           "day": 1,
#           "hour": 8,
#           "minute": 0,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 15
#           }
#         },
#         "close": {
#           "day": 1,
#           "hour": 21,
#           "minute": 30,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 15
#           }
#         }
#       },
#       {
#         "open": {
#           "day": 2,
#           "hour": 8,
#           "minute": 0,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 16
#           }
#         },
#         "close": {
#           "day": 2,
#           "hour": 21,
#           "minute": 30,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 16
#           }
#         }
#       },
#       {
#         "open": {
#           "day": 3,
#           "hour": 8,
#           "minute": 0,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 17
#           }
#         },
#         "close": {
#           "day": 3,
#           "hour": 21,
#           "minute": 30,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 17
#           }
#         }
#       },
#       {
#         "open": {
#           "day": 4,
#           "hour": 8,
#           "minute": 0,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 18
#           }
#         },
#         "close": {
#           "day": 4,
#           "hour": 21,
#           "minute": 30,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 18
#           }
#         }
#       },
#       {
#         "open": {
#           "day": 5,
#           "hour": 8,
#           "minute": 0,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 19
#           }
#         },
#         "close": {
#           "day": 5,
#           "hour": 21,
#           "minute": 30,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 19
#           }
#         }
#       },
#       {
#         "open": {
#           "day": 6,
#           "hour": 8,
#           "minute": 0,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 20
#           }
#         },
#         "close": {
#           "day": 6,
#           "hour": 21,
#           "minute": 30,
#           "date": {
#             "year": 2025,
#             "month": 9,
#             "day": 20
#           }
#         }
#       }
#     ],
#     "weekdayDescriptions": [
#       "Monday: 8:00 AM – 9:30 PM",
#       "Tuesday: 8:00 AM – 9:30 PM",
#       "Wednesday: 8:00 AM – 9:30 PM",
#       "Thursday: 8:00 AM – 9:30 PM",
#       "Friday: 8:00 AM – 9:30 PM",
#       "Saturday: 8:00 AM – 9:30 PM",
#       "Sunday: 8:00 AM – 9:30 PM"
#     ],
#     "nextCloseTime": "2025-09-15T14:30:00Z"
#   },
#   "primaryType": "jewelry_store",
#   "shortFormattedAddress": "130 P. Hàng Bạc, Phố cổ Hà Nội, Hàng Bạc",
#   "reviews": [
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/Ci9DQUlRQUNvZENodHljRjlvT2tJNVEwNVdZM2hKVG5kMWJHSnNjakp2UmpCcVVsRRAB",
#       "relativePublishTimeDescription": "a week ago",
#       "rating": 5,
#       "text": {
#         "text": "I am positively surprised by this shop. The owner (and elder man) operates very professionally and I got an even better rate than Google told me so I am more than satisfied with the service here. I can recommend you to go change money early in the morning as the rates appear to be best early in the day.",
#         "languageCode": "en"
#       },
#       "originalText": {
#         "text": "I am positively surprised by this shop. The owner (and elder man) operates very professionally and I got an even better rate than Google told me so I am more than satisfied with the service here. I can recommend you to go change money early in the morning as the rates appear to be best early in the day.",
#         "languageCode": "en"
#       },
#       "authorAttribution": {
#         "displayName": "Yo Momma",
#         "uri": "https://www.google.com/maps/contrib/101285014050628556316/reviews",
#         "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjXBmnoliBf98lmiRyT3K66nylLhYzB41niScFb_iQdiK1jXyX9w=s128-c0x00000000-cc-rp-mo-ba3"
#       },
#       "publishTime": "2025-09-01T16:27:52.827859842Z",
#       "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT2tJNVEwNVdZM2hKVG5kMWJHSnNjakp2UmpCcVVsRRAB&d=17924085&t=1",
#       "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT2tJNVEwNVdZM2hKVG5kMWJHSnNjakp2UmpCcVVsRRAB!2m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/ChZDSUhNMG9nS0VLS0I3NVh0dzhES2R3EAE",
#       "relativePublishTimeDescription": "3 months ago",
#       "rating": 5,
#       "text": {
#         "text": "Really recommended! They don’t try to scam! I converted VND to MYR and almost got the whole conversion only lost about 80k in the process which isn’t bad!",
#         "languageCode": "en"
#       },
#       "originalText": {
#         "text": "Really recommended! They don’t try to scam! I converted VND to MYR and almost got the whole conversion only lost about 80k in the process which isn’t bad!",
#         "languageCode": "en"
#       },
#       "authorAttribution": {
#         "displayName": "Cate Wall",
#         "uri": "https://www.google.com/maps/contrib/113826697698379774832/reviews",
#         "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocI6uDX5zPlNbyTpSUn6h0KpWZZAhc7X5Ii39TVeNxMd4-KZ8A=s128-c0x00000000-cc-rp-mo"
#       },
#       "publishTime": "2025-05-23T07:56:12.150726Z",
#       "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VLS0I3NVh0dzhES2R3EAE&d=17924085&t=1",
#       "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VLS0I3NVh0dzhES2R3EAE!2m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/Ci9DQUlRQUNvZENodHljRjlvT25wSWRsQkdVRVJtVkdsRFJqaFRSQzFoWVVsNk1GRRAB",
#       "relativePublishTimeDescription": "a month ago",
#       "rating": 5,
#       "text": {
#         "text": "Best place to change money! I don’t know how they are making money since their rates are even better than Google rates. My friend and I did use big Japanese yen notes that were clean and neat so no problems with getting notes rejected",
#         "languageCode": "en"
#       },
#       "originalText": {
#         "text": "Best place to change money! I don’t know how they are making money since their rates are even better than Google rates. My friend and I did use big Japanese yen notes that were clean and neat so no problems with getting notes rejected",
#         "languageCode": "en"
#       },
#       "authorAttribution": {
#         "displayName": "Amy L",
#         "uri": "https://www.google.com/maps/contrib/105748745516838562600/reviews",
#         "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocKLall13j-6l_k93i7QIaYof2qVFvMd6aUAN2Ka8dcnwpjcM30d=s128-c0x00000000-cc-rp-mo-ba2"
#       },
#       "publishTime": "2025-07-22T07:06:35.273104824Z",
#       "flagContentUri": "https://www.google.com/local/review/rap/report?postId=Ci9DQUlRQUNvZENodHljRjlvT25wSWRsQkdVRVJtVkdsRFJqaFRSQzFoWVVsNk1GRRAB&d=17924085&t=1",
#       "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sCi9DQUlRQUNvZENodHljRjlvT25wSWRsQkdVRVJtVkdsRFJqaFRSQzFoWVVsNk1GRRAB!2m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/ChZDSUhNMG9nS0VJQ0FnTURvX2F1eUhBEAE",
#       "relativePublishTimeDescription": "4 months ago",
#       "rating": 5,
#       "text": {
#         "text": "Got best rate in Hanoi for GBP conversion.\nVery friendly and professional and counted out amount to show me was correct to agreed rate.",
#         "languageCode": "en"
#       },
#       "originalText": {
#         "text": "Got best rate in Hanoi for GBP conversion.\nVery friendly and professional and counted out amount to show me was correct to agreed rate.",
#         "languageCode": "en"
#       },
#       "authorAttribution": {
#         "displayName": "Stephen Cross",
#         "uri": "https://www.google.com/maps/contrib/116351489719137080239/reviews",
#         "photoUri": "https://lh3.googleusercontent.com/a/ACg8ocIspNuwa_v8om8vT0bqm2TUJwOlKbTOaakoanmIHT9d_J9vpQ=s128-c0x00000000-cc-rp-mo"
#       },
#       "publishTime": "2025-04-28T03:59:01.639138Z",
#       "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VJQ0FnTURvX2F1eUhBEAE&d=17924085&t=1",
#       "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VJQ0FnTURvX2F1eUhBEAE!2m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/ChZDSUhNMG9nS0VLX2QtYzd2LWJERENBEAE",
#       "relativePublishTimeDescription": "3 months ago",
#       "rating": 1,
#       "text": {
#         "text": "They had good rates but were dishonest. Went in to exchange today (May 20th, 2025) at around 11:30AM to exchange $500 USD and got the rates of $26250 VND per $100 (comes to $13.125M VND for $500 USD). However, after leaving the area, I counted my money and realized I have gave them $600 USD instead. An honest shop would have returned this to the customer.",
#         "languageCode": "en"
#       },
#       "originalText": {
#         "text": "They had good rates but were dishonest. Went in to exchange today (May 20th, 2025) at around 11:30AM to exchange $500 USD and got the rates of $26250 VND per $100 (comes to $13.125M VND for $500 USD). However, after leaving the area, I counted my money and realized I have gave them $600 USD instead. An honest shop would have returned this to the customer.",
#         "languageCode": "en"
#       },
#       "authorAttribution": {
#         "displayName": "Anh Tran",
#         "uri": "https://www.google.com/maps/contrib/114805446819442391449/reviews",
#         "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjVEfjYw89CFGT8pp4UKIUv_aqHvmkGLNmqSJRUGLCz2-1sOC0M_=s128-c0x00000000-cc-rp-mo-ba2"
#       },
#       "publishTime": "2025-05-20T06:54:51.094967Z",
#       "flagContentUri": "https://www.google.com/local/review/rap/report?postId=ChZDSUhNMG9nS0VLX2QtYzd2LWJERENBEAE&d=17924085&t=1",
#       "googleMapsUri": "https://www.google.com/maps/reviews/data=!4m6!14m5!1m4!2m3!1sChZDSUhNMG9nS0VLX2QtYzd2LWJERENBEAE!2m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     }
#   ],
#   "photos": [
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpdoIoS-WhUvsF8Jzf4jb4GIyH4I50UvqNHvtuYht9jr9m0H4gJKKt-PbjeQ1dvmHCbst4zS0otKPIvEg58DJeiuYmjCw8W8oXnGZVfbkD4fTY50GJxEikmWPOhVlqVRBxGUZhhEV4DF9cVxuqaisVMRawFgEELtvOuQ4IYk-Zs2a3V-phOy6aIDImFknDxs-5-GPKXVR096tJNh-u8QYbf5AW6ZhDXjukErRHTrGBGKxnP8cxvbjRFHoWF4Y5G7pbP0UdRrxbznM0AHhTvzaz7UMU1kex3tOOsj-H0a1Vgm3g",
#       "widthPx": 1125,
#       "heightPx": 1628,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipO9D4QgCdPfa4KYCoIvzBDflJ27aD8izd0NhiJT&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipO9D4QgCdPfa4KYCoIvzBDflJ27aD8izd0NhiJT!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpcT0cj9aCq1LPTnp0YqjVFtgZ888Xu3lGujVws372sXaSTD8bDPJdsx_gmBW08mV-iS6E2LcSfl7NIEvTD_j2RC1GrbWDUHDjIIoMdoGwJEdQAOQkJ-9lWmDZAeD6nFn5fS9bPXc1azg-SrBhR20hedB0IIK5MC850_XbDm2XTytoIB20qOunKJSkIR-m1YtwQdrqJha5cgaHrZAvG6jV971Z6ebIHvurnr-kXBSY6ws22DKEUHbFDcMUVlIUp9CKD_ZVAu6Oc4W1vZXOIW-8qsC6Dybe2eoSvNA5B1JLGf9Q",
#       "widthPx": 4554,
#       "heightPx": 2157,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipNWCiWspnkQ_7ckcDBq4xzY67kXVjH9wRdqSep3&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipNWCiWspnkQ_7ckcDBq4xzY67kXVjH9wRdqSep3!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpcM_SN8hgvTwMJiPfkft_Gs7aA77r9UDxCfM12-vQJ_I1YOc-cZlJLwRSondMty7tFyeI63Cm5eUS4jtuy5249Lp4RRwbu7A5KcG7VaLUStczznMdRoL79dfHfWUlhsVFycsJkYTFNrCMdfE8FmIcoe1b5a6_XwZBiX8HaBiNNt6Ovd07iW3qhivDbXNuW364t90RLq6NQEf_rI6Xly-_bgICGD22-y-WwchENYh92xBAyt2aZS8DuhoiwB8Tit0K9hAzAvC7EspgfaM7r_YWHPrUqEn5nTlPDI8MwLHy6h2A",
#       "widthPx": 2814,
#       "heightPx": 2907,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipNAKx8lt87_7rKbbo9z9-eZ_DpQUcFOvbwcIOeO&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipNAKx8lt87_7rKbbo9z9-eZ_DpQUcFOvbwcIOeO!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpfT3Ad2FxHKwS0_ljbsKjSDLIMEM4dnlmm7XEklqEv71w6aMJhO-gwOR_EWvM4lgYMjdIP0CinyEe9O0qTFHal8YQmY2-jb83gZX4g7OGzdXBRwtxzP_pXS27hBWcEjKv9JTF12GEJbyP_Iy_fqQ2fruwZDMZu5NEO-JEYj2QCqG-d8BLksjtgHG5h-5_W8BEtSjVmD3NiyDLKF6OqW5_Yx-tEqodNVYVnCRUZVVUM0MIqjoeenxpjsZHQfor_lDwnxk4Bq_jd4T3MnhA_WL_rNJ4VZlaRhqIknY6UDYbgM6Q",
#       "widthPx": 2863,
#       "heightPx": 2964,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipMSvm0va4qejSZbjiVrTKTa60SY-6uAuJ15efGH&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipMSvm0va4qejSZbjiVrTKTa60SY-6uAuJ15efGH!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpf47AI3YwMywBEzOwalMmCHIYQXwSmlIiOIFhZAb4NpsBbqOIZD5zdRod1oaaA2Z0do_v-xRH31Fj6yQrJRolzKGQHBKWDb8_S4EYCWbyBMvuqnQzozOkaVyQhQy9NOmSfnDdsMnZBzIde8m2wq_AFSsk355Jl58LC23YG0sRC9_23nlnLg3053noi-PjOxCq3obhw1y-HOGuJ4tgVfZ4F8JOJ_uqCLjCyhuE4BrUufWuMO3b19nq7fNLpQCQEcNg-9tthPpxB1DKXqthz4kiqPm7PGTVm_XHRNJYdpFGc9DQ",
#       "widthPx": 3600,
#       "heightPx": 4800,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipPqYrvQGJdNpwDan_5JGyK1ZK-HwNrFLU7nV1Cs&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipPqYrvQGJdNpwDan_5JGyK1ZK-HwNrFLU7nV1Cs!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpdlRKadYxaM2tBhERX0U74wxYPpcHS6GxSx22k8Nyys3kduXTrOZvpd9ujmiPV_ZgkhTuQ56G0XNwogRuzGOpXWhacNo2Otjtmv7WOA3gzkDaxEMLpaohOQLuxbHDip18i-9zpVgv73JL_LvkEdIdgQ0_mq4CfR2F_0Yb8i635NCpdQJsRc-WJu7LFrlTS9nabC7Xo2l4hPn2g4uiiWrt1mdMirqwKYfAHLfD9Cvb5_TY2nLETj3pwrDCmh4cUUf9kAlQ9pOR0pM1gUFB5o9R4HGvXsExwxgG9qXUVkAavjxw",
#       "widthPx": 3140,
#       "heightPx": 2918,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipOZ-LzDac49AdAMIAXbqLrhwLvHBsGa8kJmxkDI&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipOZ-LzDac49AdAMIAXbqLrhwLvHBsGa8kJmxkDI!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpcXN-Lk0yhjT9aEBOB41IjxbEGUpTPkW2LGU_4Yv45ys_KmHRKQqlsMxv1wRlNZdJ9albQiKGUqmC4c5YAa_ZAzTab7PBYc7mSEBaG0E-fpFd9XU2-Tgj8niWH5z1DZREuomzPzA7Zq_p6t0s9V6KdtbWJx1rAjxNDgp-0EvizNVAlsYDE7BlXtlca3WcuWUzPigJNhAkdjjvRAfcefw2Sd6SoXpsFfHcK9t4WrSZzrsAgUwPiri3DwiX2DaPqHkpgUpe4-zCCsai3_NEphpbp67rxVjDd_SdLUrt_uCgoOtg",
#       "widthPx": 3600,
#       "heightPx": 4800,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipOeYv_bcIzu_3dZ_Aal6NDp6bmTfvD6YYnPENNy&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipOeYv_bcIzu_3dZ_Aal6NDp6bmTfvD6YYnPENNy!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpdCfitx3VS8tchqZpt50Udb68G-5JxyU_OQVtuVHoSHHIiBr7y4VtZG0z_v-vo6irkpmwz1UFxkmysPnHv4OxK-7dRXV77P490E2-hxgfb0NMUHtGeCjH1y-3C3Ip2z8ZYiuaNVmgZeBYS7Z_JYxVNtpDU4yxYLYuR08uxqW9h1gnvEPQGGmsvXD534N4VV7f7WiXEQMBizadikNcqP4vYmOnS-YcjVL9wzbZZjKxmY7wwV7_ivlnqPLP2gOnoEW1T7xzN1Ohmrgx4w_5_C9rzv0I0DAN1cC07dFQ_JFvW4sw",
#       "widthPx": 1285,
#       "heightPx": 1682,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipPk3mtKYYpxSgtwyMB-gaO3AmhXyA2NY4V1hTnG&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipPk3mtKYYpxSgtwyMB-gaO3AmhXyA2NY4V1hTnG!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpdHJnbyRKpUmcLh9hPqgahjReGn3ii-uDnosleJ4XknrxJNCIkBhX-uX15Ctv6LBcVhb8zvP9k3B4PShuNQgKVIh3pKIHutnykqxJ05kqAUZ2RHf6pSEp33n5oXALArbAdkc_L6HQN5rjbfoF8LTOX1GOEiWYJJceeEOaBNqLNyot1r8F9irwk7DmPH0jRlc1OobGWCWXhN6yzewD4txlo2R-Fs15co2XSLzBABfdrFoUTh1vjkH_CB9ERGwPO-0LdNgmAhShOH9qO_FEiUw0pXRblv5xF63BXDOC5An4bDzQ",
#       "widthPx": 3144,
#       "heightPx": 4030,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipPs_nE8-Ho1ZBNj3a8zwwZYkzowxypcbZbZ8Y0e&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipPs_nE8-Ho1ZBNj3a8zwwZYkzowxypcbZbZ8Y0e!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpe4OG8i3Zv5LV0uU5_Oqrrcm7YwQ_XyZWCJiznm7wCUd5xHfDZmq0j0pReMyo6VSoRTIP6l3L91_Y25iuLLc_wFAEJ4K__E-Yc5k9ZEWiA96CJqFtPxTTE_EaWs4Gxz0y8VZlk2ummUXOlqDUyTwoPUKybEhEv_-UOhPE28h3r0R698MCH4IIai0Tm6O9_UUimcvLqBfh2tdpadLmdc82V4zvCHPiKNk0b36jDDaOqVG88M-qrCo3BEYRIT6f7xelwbcj0vsFrZ_yg-QwmRC_l8jmNc11A4egQaNux531tRXQ",
#       "widthPx": 4624,
#       "heightPx": 3468,
#       "authorAttributions": [
#         {
#           "displayName": "QUANG HUY GEMSTONE",
#           "uri": "https://maps.google.com/maps/contrib/106880300482401157830",
#           "photoUri": "https://lh3.googleusercontent.com/a-/ALV-UjWsolOCVhHpLiDKzqGiHyb1N1qH78DAoB10K74cmC9-tZ4KA1Bn=s100-p-k-no-mo"
#         }
#       ],
#       "flagContentUri": "https://www.google.com/local/imagery/report/?cb_client=maps_api_places.places_api&image_key=!1e10!2sAF1QipNe3tr8SKyUmHIBAAfaJzMT0vwCho0knhQ-XVV8&hl=en&gl=jp",
#       "googleMapsUri": "https://www.google.com/maps/place//data=!3m4!1e2!3m2!1sAF1QipNe3tr8SKyUmHIBAAfaJzMT0vwCho0knhQ-XVV8!2e10!4m2!3m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d"
#     }
#   ],
#   "paymentOptions": {
#     "acceptsDebitCards": true,
#     "acceptsCashOnly": false
#   },
#   "accessibilityOptions": {
#     "wheelchairAccessibleParking": false,
#     "wheelchairAccessibleEntrance": false
#   },
#   "addressDescriptor": {
#     "landmarks": [
#       {
#         "name": "places/ChIJp0o4Er6rNTERjlTif_IXU1k",
#         "placeId": "ChIJp0o4Er6rNTERjlTif_IXU1k",
#         "displayName": {
#           "text": "Hanoi Old Quarter",
#           "languageCode": "en"
#         },
#         "types": [
#           "establishment",
#           "point_of_interest",
#           "tourist_attraction"
#         ],
#         "spatialRelationship": "ACROSS_THE_ROAD",
#         "straightLineDistanceMeters": 31.839758,
#         "travelDistanceMeters": 27.770699
#       },
#       {
#         "name": "places/ChIJB1EGIX-rNTER9GVryLt_d3c",
#         "placeId": "ChIJB1EGIX-rNTER9GVryLt_d3c",
#         "displayName": {
#           "text": "MẸT Vietnamese restaurant & Vegetarian Food 3",
#           "languageCode": "vi"
#         },
#         "types": [
#           "establishment",
#           "food",
#           "point_of_interest",
#           "restaurant"
#         ],
#         "spatialRelationship": "DOWN_THE_ROAD",
#         "straightLineDistanceMeters": 38.073086,
#         "travelDistanceMeters": 36.154663
#       },
#       {
#         "name": "places/ChIJifwNDb-rNTERvWGeAESCzpI",
#         "placeId": "ChIJifwNDb-rNTERvWGeAESCzpI",
#         "displayName": {
#           "text": "Giang Son Gemstone Jewelry Co.,Ltd",
#           "languageCode": "en"
#         },
#         "types": [
#           "establishment",
#           "finance",
#           "point_of_interest"
#         ],
#         "spatialRelationship": "BESIDE",
#         "straightLineDistanceMeters": 8.657147,
#         "travelDistanceMeters": 7.9427586
#       },
#       {
#         "name": "places/ChIJ94wpQL-rNTERgZw5CuatajA",
#         "placeId": "ChIJ94wpQL-rNTERgZw5CuatajA",
#         "displayName": {
#           "text": "Old Quarter View Hanoi Hostel",
#           "languageCode": "en"
#         },
#         "types": [
#           "establishment",
#           "lodging",
#           "point_of_interest"
#         ],
#         "straightLineDistanceMeters": 61.618645,
#         "travelDistanceMeters": 332.25366
#       },
#       {
#         "name": "places/ChIJDfxKh8yrNTERxxSVKik6HY4",
#         "placeId": "ChIJDfxKh8yrNTERxxSVKik6HY4",
#         "displayName": {
#           "text": "OYO 604 Queen Hotel (spot-on)",
#           "languageCode": "en"
#         },
#         "types": [
#           "establishment",
#           "lodging",
#           "point_of_interest"
#         ],
#         "spatialRelationship": "DOWN_THE_ROAD",
#         "straightLineDistanceMeters": 26.422781,
#         "travelDistanceMeters": 24.600046
#       }
#     ],
#     "areas": [
#       {
#         "name": "places/ChIJUcPpeMCrNTERqzzzgwvazX4",
#         "placeId": "ChIJUcPpeMCrNTERqzzzgwvazX4",
#         "displayName": {
#           "text": "Hàng Bạc",
#           "languageCode": "vi"
#         },
#         "containment": "OUTSKIRTS"
#       },
#       {
#         "name": "places/ChIJ95W4Ib-rNTERpMcyh8TGG2Q",
#         "placeId": "ChIJ95W4Ib-rNTERpMcyh8TGG2Q",
#         "displayName": {
#           "text": "Old Quarter",
#           "languageCode": "en"
#         },
#         "containment": "WITHIN"
#       },
#       {
#         "name": "places/ChIJseZJGr-rNTER7N_XTUAPRYA",
#         "placeId": "ChIJseZJGr-rNTER7N_XTUAPRYA",
#         "displayName": {
#           "text": "Hàng Đào",
#           "languageCode": "en"
#         },
#         "containment": "OUTSKIRTS"
#       }
#     ]
#   },
#   "googleMapsLinks": {
#     "directionsUri": "https://www.google.com/maps/dir//''/data=!4m7!4m6!1m1!4e2!1m2!1m1!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d!3e0?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQABgBIAA",
#     "placeUri": "https://maps.google.com/?cid=8745706810439273565&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQABgBIAA",
#     "writeAReviewUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d!12e1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQABgBIAA",
#     "reviewsUri": "https://www.google.com/maps/place//data=!4m4!3m3!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d!9m1!1b1?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQABgBIAA",
#     "photosUri": "https://www.google.com/maps/place//data=!4m3!3m2!1s0x3135abbf12a1a2ef:0x795efe01e1f28c5d!10e5?g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQABgBIAA"
#   },
#   "timeZone": {
#     "id": "Asia/Saigon"
#   },
#   "postalAddress": {
#     "regionCode": "VN",
#     "languageCode": "en",
#     "administrativeArea": "Hanoi",
#     "locality": "Hoàn Kiếm",
#     "sublocality": "Hàng Buồm",
#     "addressLines": [
#       "130 P. Hàng Bạc"
#     ]
#   }
# }

# %%
from typing import Dict, List, Optional
import re
from datetime import datetime

def preprocess_place(p: dict) -> dict:
    """
    Preprocess a place dictionary from Google Places API.
    Args:
        p (dict): Raw place data from the API.
    Returns:
        dict: Processed place data with cleaned and standardized fields.
    """
    processed = {}

    # 1. Basic Identification
    processed["id"] = p.get("id", "").strip()
    if not processed["id"]:
        raise ValueError("Missing required field: id")

    # 2. Name and Display Name
    processed["name"] = p.get("name", "").strip()
    display_name = p.get("displayName", {})
    processed["display_name"] = display_name.get("text", processed["name"]).strip()
    processed["language_code"] = display_name.get("languageCode", "en").strip()

    # 3. Types
    processed["types"] = p.get("types", [])
    processed["primary_type"] = p.get("primaryType", processed["types"][0] if processed["types"] else "").strip()
    primary_type_display = p.get("primaryTypeDisplayName", {})
    processed["primary_type_display_name"] = primary_type_display.get("text", processed["primary_type"]).strip()

    # 4. Phone Numbers
    processed["phone_number"] = p.get("internationalPhoneNumber", p.get("nationalPhoneNumber", "")).strip()
    if processed["phone_number"]:
        # Remove non-digit characters except '+' for international format
        processed["phone_number"] = re.sub(r"[^\d+]", "", processed["phone_number"])

    # 5. Address
    processed["formatted_address"] = p.get("formattedAddress", "").strip()
    processed["short_formatted_address"] = p.get("shortFormattedAddress", processed["formatted_address"]).strip()

    # 6. Location
    location = p.get("location", {})
    processed["latitude"] = float(location.get("latitude", 0))
    processed["longitude"] = float(location.get("longitude", 0))
    # Validate coordinates
    if not (-90 <= processed["latitude"] <= 90 and -180 <= processed["longitude"] <= 180):
        processed["latitude"], processed["longitude"] = 0, 0  # Default to invalid coordinates

    # 7. Viewport (optional, simplified)
    viewport = p.get("viewport", {})
    processed["viewport"] = {
        "low": {
            "latitude": float(viewport.get("low", {}).get("latitude", 0)),
            "longitude": float(viewport.get("low", {}).get("longitude", 0))
        },
        "high": {
            "latitude": float(viewport.get("high", {}).get("latitude", 0)),
            "longitude": float(viewport.get("high", {}).get("longitude", 0))
        }
    }

    # 8. Rating and Reviews
    processed["rating"] = float(p.get("rating", 0))
    processed["user_rating_count"] = int(p.get("userRatingCount", 0))
    reviews = p.get("reviews", [])
    processed["reviews"] = [
        {
            "name": r.get("name", "").strip(),
            "rating": float(r.get("rating", 0)),
            "publish_time": r.get("publishTime", ""),
            "relative_publish_time": r.get("relativePublishTimeDescription", "").strip()
        } for r in reviews # [:3]  # Limit to 3 reviews for brevity
    ]

    # 9. URLs
    processed["google_maps_uri"] = p.get("googleMapsUri", "").strip()
    processed["website_uri"] = p.get("websiteUri", "").strip()
    # Validate URLs
    for url_field in ["google_maps_uri", "website_uri"]:
        if processed[url_field] and not processed[url_field].startswith("http"):
            processed[url_field] = f"https://{processed[url_field]}"

    # 10. Opening Hours
    regular_hours = p.get("regularOpeningHours", {})
    processed["open_now"] = bool(regular_hours.get("openNow", False))
    processed["weekday_descriptions"] = regular_hours.get("weekdayDescriptions", [])
    processed["opening_hours"] = [
        {
            "open": {
                "day": period.get("open", {}).get("day", 0),
                "hour": period.get("open", {}).get("hour", 0),
                "minute": period.get("open", {}).get("minute", 0)
            },
            "close": {
                "day": period.get("close", {}).get("day", 0),
                "hour": period.get("close", {}).get("hour", 0),
                "minute": period.get("close", {}).get("minute", 0)
            }
        } for period in regular_hours.get("periods", [])
    ]

    # 11. Business Status
    processed["business_status"] = p.get("businessStatus", 0)  # Assume 0 = OPERATIONAL

    # 12. Services (boolean flags)
    services = [
        "takeout", "delivery", "dineIn", "curbsidePickup", "reservable",
        "servesBreakfast", "servesLunch", "servesDinner", "servesBeer",
        "servesWine", "servesBrunch", "servesVegetarianFood",
        "outdoorSeating", "liveMusic", "menuForChildren", "servesCocktails",
        "servesDessert", "servesCoffee", "goodForChildren", "allowsDogs",
        "restroom", "goodForGroups", "goodForWatchingSports"
    ]
    for service in services:
        processed[service] = bool(p.get(service, False))

    # 13. Payment Options
    payment_options = p.get("paymentOptions", {})
    processed["payment_options"] = {
        "accepts_credit_cards": bool(payment_options.get("acceptsCreditCards", False)),
        "accepts_debit_cards": bool(payment_options.get("acceptsDebitCards", False)),
        "accepts_cash_only": bool(payment_options.get("acceptsCashOnly", False)),
        "accepts_nfc": bool(payment_options.get("acceptsNfc", False))
    }

    # 14. Parking Options
    parking_options = p.get("parkingOptions", {})
    processed["parking_options"] = {
        "free_parking_lot": bool(parking_options.get("freeParkingLot", False)),
        "paid_parking_lot": bool(parking_options.get("paidParkingLot", False)),
        "free_street_parking": bool(parking_options.get("freeStreetParking", False)),
        "paid_street_parking": bool(parking_options.get("paidStreetParking", False)),
        "valet_parking": bool(parking_options.get("valetParking", False)),
        "free_garage_parking": bool(parking_options.get("freeGarageParking", False)),
        "paid_garage_parking": bool(parking_options.get("paidGarageParking", False))
    }

    # 15. Accessibility Options
    accessibility_options = p.get("accessibilityOptions", {})
    processed["accessibility_options"] = {
        "wheelchair_accessible_parking": bool(accessibility_options.get("wheelchairAccessibleParking", False)),
        "wheelchair_accessible_entrance": bool(accessibility_options.get("wheelchairAccessibleEntrance", False)),
        "wheelchair_accessible_restroom": bool(accessibility_options.get("wheelchairAccessibleRestroom", False)),
        "wheelchair_accessible_seating": bool(accessibility_options.get("wheelchairAccessibleSeating", False))
    }

    # 16. Photos (limit to first photo for simplicity)
    photos = p.get("photos", [])
    processed["photos"] = [
        {
            "name": photo.get("name", "").strip(),
            "author": photo.get("authorAttributions", [{}])[0].get("displayName", "").strip()
        } for photo in photos # [:1]  # Limit to 1 photo
    ]

    # 17. Editorial Summary
    editorial_summary = p.get("editorialSummary", {})
    processed["editorial_summary"] = editorial_summary.get("text", "").strip()

    # 18. Price Level
    processed["price_level"] = int(p.get("priceLevel", 0))

    return processed

print(json.dumps(preprocess_place(places[200]), indent=2, ensure_ascii=False, default=str))
# Out:
# {
#   "id": "ChIJ76KhEr-rNTERXYzy4QH-Xnk",
#   "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk",
#   "display_name": "Quang Huy Gemstone",
#   "language_code": "en",
#   "types": [
#     "jewelry_store",
#     "finance",
#     "store",
#     "point_of_interest",
#     "establishment"
#   ],
#   "primary_type": "jewelry_store",
#   "primary_type_display_name": "Jewelry store",
#   "phone_number": "+842438267117",
#   "formatted_address": "130 P. Hàng Bạc, Hàng Buồm, Hoàn Kiếm, Hà Nội, Vietnam",
#   "short_formatted_address": "130 P. Hàng Bạc, Phố cổ Hà Nội, Hàng Bạc",
#   "latitude": 21.0341679,
#   "longitude": 105.850923,
#   "viewport": {
#     "low": {
#       "latitude": 21.0327839697085,
#       "longitude": 105.84957636970849
#     },
#     "high": {
#       "latitude": 21.035481930291507,
#       "longitude": 105.8522743302915
#     }
#   },
#   "rating": 4.7,
#   "user_rating_count": 683,
#   "reviews": [
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/Ci9DQUlRQUNvZENodHljRjlvT2tJNVEwNVdZM2hKVG5kMWJHSnNjakp2UmpCcVVsRRAB",
#       "rating": 5.0,
#       "publish_time": "2025-09-01T16:27:52.827859842Z",
#       "relative_publish_time": "a week ago"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/ChZDSUhNMG9nS0VLS0I3NVh0dzhES2R3EAE",
#       "rating": 5.0,
#       "publish_time": "2025-05-23T07:56:12.150726Z",
#       "relative_publish_time": "3 months ago"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/Ci9DQUlRQUNvZENodHljRjlvT25wSWRsQkdVRVJtVkdsRFJqaFRSQzFoWVVsNk1GRRAB",
#       "rating": 5.0,
#       "publish_time": "2025-07-22T07:06:35.273104824Z",
#       "relative_publish_time": "a month ago"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/ChZDSUhNMG9nS0VJQ0FnTURvX2F1eUhBEAE",
#       "rating": 5.0,
#       "publish_time": "2025-04-28T03:59:01.639138Z",
#       "relative_publish_time": "4 months ago"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/reviews/ChZDSUhNMG9nS0VLX2QtYzd2LWJERENBEAE",
#       "rating": 1.0,
#       "publish_time": "2025-05-20T06:54:51.094967Z",
#       "relative_publish_time": "3 months ago"
#     }
#   ],
#   "google_maps_uri": "https://maps.google.com/?cid=8745706810439273565&g_mp=Cidnb29nbGUubWFwcy5wbGFjZXMudjEuUGxhY2VzLlNlYXJjaFRleHQQABgBIAA",
#   "website_uri": "",
#   "open_now": true,
#   "weekday_descriptions": [
#     "Monday: 8:00 AM – 9:30 PM",
#     "Tuesday: 8:00 AM – 9:30 PM",
#     "Wednesday: 8:00 AM – 9:30 PM",
#     "Thursday: 8:00 AM – 9:30 PM",
#     "Friday: 8:00 AM – 9:30 PM",
#     "Saturday: 8:00 AM – 9:30 PM",
#     "Sunday: 8:00 AM – 9:30 PM"
#   ],
#   "opening_hours": [
#     {
#       "open": {
#         "day": 0,
#         "hour": 8,
#         "minute": 0
#       },
#       "close": {
#         "day": 0,
#         "hour": 21,
#         "minute": 30
#       }
#     },
#     {
#       "open": {
#         "day": 1,
#         "hour": 8,
#         "minute": 0
#       },
#       "close": {
#         "day": 1,
#         "hour": 21,
#         "minute": 30
#       }
#     },
#     {
#       "open": {
#         "day": 2,
#         "hour": 8,
#         "minute": 0
#       },
#       "close": {
#         "day": 2,
#         "hour": 21,
#         "minute": 30
#       }
#     },
#     {
#       "open": {
#         "day": 3,
#         "hour": 8,
#         "minute": 0
#       },
#       "close": {
#         "day": 3,
#         "hour": 21,
#         "minute": 30
#       }
#     },
#     {
#       "open": {
#         "day": 4,
#         "hour": 8,
#         "minute": 0
#       },
#       "close": {
#         "day": 4,
#         "hour": 21,
#         "minute": 30
#       }
#     },
#     {
#       "open": {
#         "day": 5,
#         "hour": 8,
#         "minute": 0
#       },
#       "close": {
#         "day": 5,
#         "hour": 21,
#         "minute": 30
#       }
#     },
#     {
#       "open": {
#         "day": 6,
#         "hour": 8,
#         "minute": 0
#       },
#       "close": {
#         "day": 6,
#         "hour": 21,
#         "minute": 30
#       }
#     }
#   ],
#   "business_status": "OPERATIONAL",
#   "takeout": false,
#   "delivery": false,
#   "dineIn": false,
#   "curbsidePickup": false,
#   "reservable": false,
#   "servesBreakfast": false,
#   "servesLunch": false,
#   "servesDinner": false,
#   "servesBeer": false,
#   "servesWine": false,
#   "servesBrunch": false,
#   "servesVegetarianFood": false,
#   "outdoorSeating": false,
#   "liveMusic": false,
#   "menuForChildren": false,
#   "servesCocktails": false,
#   "servesDessert": false,
#   "servesCoffee": false,
#   "goodForChildren": false,
#   "allowsDogs": false,
#   "restroom": false,
#   "goodForGroups": false,
#   "goodForWatchingSports": false,
#   "payment_options": {
#     "accepts_credit_cards": false,
#     "accepts_debit_cards": true,
#     "accepts_cash_only": false,
#     "accepts_nfc": false
#   },
#   "parking_options": {
#     "free_parking_lot": false,
#     "paid_parking_lot": false,
#     "free_street_parking": false,
#     "paid_street_parking": false,
#     "valet_parking": false,
#     "free_garage_parking": false,
#     "paid_garage_parking": false
#   },
#   "accessibility_options": {
#     "wheelchair_accessible_parking": false,
#     "wheelchair_accessible_entrance": false,
#     "wheelchair_accessible_restroom": false,
#     "wheelchair_accessible_seating": false
#   },
#   "photos": [
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpdoIoS-WhUvsF8Jzf4jb4GIyH4I50UvqNHvtuYht9jr9m0H4gJKKt-PbjeQ1dvmHCbst4zS0otKPIvEg58DJeiuYmjCw8W8oXnGZVfbkD4fTY50GJxEikmWPOhVlqVRBxGUZhhEV4DF9cVxuqaisVMRawFgEELtvOuQ4IYk-Zs2a3V-phOy6aIDImFknDxs-5-GPKXVR096tJNh-u8QYbf5AW6ZhDXjukErRHTrGBGKxnP8cxvbjRFHoWF4Y5G7pbP0UdRrxbznM0AHhTvzaz7UMU1kex3tOOsj-H0a1Vgm3g",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpcT0cj9aCq1LPTnp0YqjVFtgZ888Xu3lGujVws372sXaSTD8bDPJdsx_gmBW08mV-iS6E2LcSfl7NIEvTD_j2RC1GrbWDUHDjIIoMdoGwJEdQAOQkJ-9lWmDZAeD6nFn5fS9bPXc1azg-SrBhR20hedB0IIK5MC850_XbDm2XTytoIB20qOunKJSkIR-m1YtwQdrqJha5cgaHrZAvG6jV971Z6ebIHvurnr-kXBSY6ws22DKEUHbFDcMUVlIUp9CKD_ZVAu6Oc4W1vZXOIW-8qsC6Dybe2eoSvNA5B1JLGf9Q",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpcM_SN8hgvTwMJiPfkft_Gs7aA77r9UDxCfM12-vQJ_I1YOc-cZlJLwRSondMty7tFyeI63Cm5eUS4jtuy5249Lp4RRwbu7A5KcG7VaLUStczznMdRoL79dfHfWUlhsVFycsJkYTFNrCMdfE8FmIcoe1b5a6_XwZBiX8HaBiNNt6Ovd07iW3qhivDbXNuW364t90RLq6NQEf_rI6Xly-_bgICGD22-y-WwchENYh92xBAyt2aZS8DuhoiwB8Tit0K9hAzAvC7EspgfaM7r_YWHPrUqEn5nTlPDI8MwLHy6h2A",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpfT3Ad2FxHKwS0_ljbsKjSDLIMEM4dnlmm7XEklqEv71w6aMJhO-gwOR_EWvM4lgYMjdIP0CinyEe9O0qTFHal8YQmY2-jb83gZX4g7OGzdXBRwtxzP_pXS27hBWcEjKv9JTF12GEJbyP_Iy_fqQ2fruwZDMZu5NEO-JEYj2QCqG-d8BLksjtgHG5h-5_W8BEtSjVmD3NiyDLKF6OqW5_Yx-tEqodNVYVnCRUZVVUM0MIqjoeenxpjsZHQfor_lDwnxk4Bq_jd4T3MnhA_WL_rNJ4VZlaRhqIknY6UDYbgM6Q",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpf47AI3YwMywBEzOwalMmCHIYQXwSmlIiOIFhZAb4NpsBbqOIZD5zdRod1oaaA2Z0do_v-xRH31Fj6yQrJRolzKGQHBKWDb8_S4EYCWbyBMvuqnQzozOkaVyQhQy9NOmSfnDdsMnZBzIde8m2wq_AFSsk355Jl58LC23YG0sRC9_23nlnLg3053noi-PjOxCq3obhw1y-HOGuJ4tgVfZ4F8JOJ_uqCLjCyhuE4BrUufWuMO3b19nq7fNLpQCQEcNg-9tthPpxB1DKXqthz4kiqPm7PGTVm_XHRNJYdpFGc9DQ",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpdlRKadYxaM2tBhERX0U74wxYPpcHS6GxSx22k8Nyys3kduXTrOZvpd9ujmiPV_ZgkhTuQ56G0XNwogRuzGOpXWhacNo2Otjtmv7WOA3gzkDaxEMLpaohOQLuxbHDip18i-9zpVgv73JL_LvkEdIdgQ0_mq4CfR2F_0Yb8i635NCpdQJsRc-WJu7LFrlTS9nabC7Xo2l4hPn2g4uiiWrt1mdMirqwKYfAHLfD9Cvb5_TY2nLETj3pwrDCmh4cUUf9kAlQ9pOR0pM1gUFB5o9R4HGvXsExwxgG9qXUVkAavjxw",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpcXN-Lk0yhjT9aEBOB41IjxbEGUpTPkW2LGU_4Yv45ys_KmHRKQqlsMxv1wRlNZdJ9albQiKGUqmC4c5YAa_ZAzTab7PBYc7mSEBaG0E-fpFd9XU2-Tgj8niWH5z1DZREuomzPzA7Zq_p6t0s9V6KdtbWJx1rAjxNDgp-0EvizNVAlsYDE7BlXtlca3WcuWUzPigJNhAkdjjvRAfcefw2Sd6SoXpsFfHcK9t4WrSZzrsAgUwPiri3DwiX2DaPqHkpgUpe4-zCCsai3_NEphpbp67rxVjDd_SdLUrt_uCgoOtg",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpdCfitx3VS8tchqZpt50Udb68G-5JxyU_OQVtuVHoSHHIiBr7y4VtZG0z_v-vo6irkpmwz1UFxkmysPnHv4OxK-7dRXV77P490E2-hxgfb0NMUHtGeCjH1y-3C3Ip2z8ZYiuaNVmgZeBYS7Z_JYxVNtpDU4yxYLYuR08uxqW9h1gnvEPQGGmsvXD534N4VV7f7WiXEQMBizadikNcqP4vYmOnS-YcjVL9wzbZZjKxmY7wwV7_ivlnqPLP2gOnoEW1T7xzN1Ohmrgx4w_5_C9rzv0I0DAN1cC07dFQ_JFvW4sw",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpdHJnbyRKpUmcLh9hPqgahjReGn3ii-uDnosleJ4XknrxJNCIkBhX-uX15Ctv6LBcVhb8zvP9k3B4PShuNQgKVIh3pKIHutnykqxJ05kqAUZ2RHf6pSEp33n5oXALArbAdkc_L6HQN5rjbfoF8LTOX1GOEiWYJJceeEOaBNqLNyot1r8F9irwk7DmPH0jRlc1OobGWCWXhN6yzewD4txlo2R-Fs15co2XSLzBABfdrFoUTh1vjkH_CB9ERGwPO-0LdNgmAhShOH9qO_FEiUw0pXRblv5xF63BXDOC5An4bDzQ",
#       "author": "QUANG HUY GEMSTONE"
#     },
#     {
#       "name": "places/ChIJ76KhEr-rNTERXYzy4QH-Xnk/photos/ATKogpe4OG8i3Zv5LV0uU5_Oqrrcm7YwQ_XyZWCJiznm7wCUd5xHfDZmq0j0pReMyo6VSoRTIP6l3L91_Y25iuLLc_wFAEJ4K__E-Yc5k9ZEWiA96CJqFtPxTTE_EaWs4Gxz0y8VZlk2ummUXOlqDUyTwoPUKybEhEv_-UOhPE28h3r0R698MCH4IIai0Tm6O9_UUimcvLqBfh2tdpadLmdc82V4zvCHPiKNk0b36jDDaOqVG88M-qrCo3BEYRIT6f7xelwbcj0vsFrZ_yg-QwmRC_l8jmNc11A4egQaNux531tRXQ",
#       "author": "QUANG HUY GEMSTONE"
#     }
#   ],
#   "editorial_summary": "",
#   "price_level": 0
# }

# %%
import json
from bson import ObjectId

# Lọc tất cả các đối tượng có primaryType là 'tourist_attraction'
tourist_attractions = [p for p in places if p.get("primaryType") == "tourist_attraction"]
print(f"Số lượng tourist_attraction: {len(tourist_attractions)}")
# # In ra 1 ví dụ
# if tourist_attractions:
#     print(json.dumps(tourist_attractions[0], indent=2, ensure_ascii=False, default=str))
# else:
#     print("Không tìm thấy đối tượng nào.")
# Out:
# Số lượng tourist_attraction: 435

# %% [markdown]
# # Tính khoảng cách dùng API
# https://rapidapi.com/sa307485/api/real-time-distance-calculator-with-map

# %%
import requests

url = "https://real-time-distance-calculator-with-map.p.rapidapi.com/rapidapi/distance-calculator/calculate.php"

querystring = {"endLongitude":"2.3522","startLongitude":"-0.1278","startLatitude":"51.5074","endLatitude":"48.8566"}

headers = {
	"x-rapidapi-key": "ffbaceaaeamsh9084aa32f4d5dfdp13028bjsn2366c1d9a5c9",
	"x-rapidapi-host": "real-time-distance-calculator-with-map.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(json.dumps(response.json(), indent=2, ensure_ascii=False, default=str))
# Out:
# {
#   "status": "success",
#   "startLatitude": "51.5074",
#   "startLongitude": "-0.1278",
#   "startLocation": "Charing Cross",
#   "endLatitude": "48.8566",
#   "endLongitude": "2.3522",
#   "endLocation": "Place de l'Hôtel de Ville",
#   "distance": {
#     "kilometers": 343.56,
#     "miles": 213.48
#   },
#   "travel_times": {
#     "plane": 0.38,
#     "train": 2.86,
#     "car": 4.29,
#     "bike": 17.18,
#     "walk": 68.71
#   },
#   "google_maps_link": "https://www.google.com/maps/dir/?api=1&origin=51.5074,-0.1278&destination=48.8566,2.3522",
#   "message": "Distance and travel time calculation successful."
# }

# %%
import requests
import json  # cần import để dùng json.dumps

url = "https://real-time-distance-calculator-with-map.p.rapidapi.com/rapidapi/distance-calculator/calculate.php"

# Thay bằng tọa độ Hà Nội và TP.HCM
querystring = {
    "startLatitude": "21.0285",   # Hà Nội
    "startLongitude": "105.8542",
    "endLatitude": "10.7626",     # TP.HCM
    "endLongitude": "106.6602"
}

headers = {
    "x-rapidapi-key": "ffbaceaaeamsh9084aa32f4d5dfdp13028bjsn2366c1d9a5c9",
    "x-rapidapi-host": "real-time-distance-calculator-with-map.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# In kết quả với định dạng đẹp + hỗ trợ tiếng Việt
print(json.dumps(response.json(), indent=2, ensure_ascii=False, default=str))
# Out:
# {
#   "status": "success",
#   "startLatitude": "21.0285",
#   "startLongitude": "105.8542",
#   "startLocation": "Phố Đinh Tiên Hoàng",
#   "endLatitude": "10.7626",
#   "endLongitude": "106.6602",
#   "endLocation": "Hẻm 189 Đường Lý Thường Kiệt",
#   "distance": {
#     "kilometers": 1144.75,
#     "miles": 711.33
#   },
#   "travel_times": {
#     "plane": 1.27,
#     "train": 9.54,
#     "car": 14.31,
#     "bike": 57.24,
#     "walk": 228.95
#   },
#   "google_maps_link": "https://www.google.com/maps/dir/?api=1&origin=21.0285,105.8542&destination=10.7626,106.6602",
#   "message": "Distance and travel time calculation successful."
# }

# %%
import requests
import json

url = "https://real-time-distance-calculator-with-map.p.rapidapi.com/rapidapi/distance-calculator/calculate.php"

# ✅ Đổi sang tọa độ Hồ Tây -> Nhà Hát Lớn Hà Nội
querystring = {
    "startLatitude": "21.0578",   # Hồ Tây
    "startLongitude": "105.8180",
    "endLatitude": "21.0247",     # Nhà Hát Lớn
    "endLongitude": "105.8575"
}

headers = {
    "x-rapidapi-key": "ffbaceaaeamsh9084aa32f4d5dfdp13028bjsn2366c1d9a5c9",
    "x-rapidapi-host": "real-time-distance-calculator-with-map.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(json.dumps(response.json(), indent=2, ensure_ascii=False, default=str))
# Out:
# {
#   "status": "success",
#   "startLatitude": "21.0578",
#   "startLongitude": "105.8180",
#   "startLocation": "Phố Quảng Khánh",
#   "endLatitude": "21.0247",
#   "endLongitude": "105.8575",
#   "endLocation": "Phố Tràng Tiền",
#   "distance": {
#     "kilometers": 5.51,
#     "miles": 3.42
#   },
#   "travel_times": {
#     "plane": 0.01,
#     "train": 0.05,
#     "car": 0.07,
#     "bike": 0.28,
#     "walk": 1.1
#   },
#   "google_maps_link": "https://www.google.com/maps/dir/?api=1&origin=21.0578,105.8180&destination=21.0247,105.8575",
#   "message": "Distance and travel time calculation successful."
# }

# %%
import redis

r = redis.Redis(host="localhost", port=6379, decode_responses=True)
print(r.ping())  # True nếu kết nối OK
r.set("test_key", "hello redis")
print(r.get("test_key"))
# Out:
# True
# hello redis
